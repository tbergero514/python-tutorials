# %%
# import numpy as np
import matplotlib as plt
import pandas as pd

df1 = pd.read_csv("C:\\Users\\T3BJ\\Desktop\\TMP\\pytest.csv")
print(df1)
# Out:
#      tgt_rt_sched_cd     usg_dt  hr  tot_rcvd_kwh  tot_dlvd_kwh
# 0                 A1  01Jan2018   1      0.000000  11779.935820
# 1                 A1  01Jan2018   2      0.000000  11775.946420
# 2                 A1  01Jan2018   3      0.000000  11612.578920
# 3                 A1  01Jan2018   4      0.000000  11690.239240
# 4                 A1  01Jan2018   5      0.000000  11973.133280
# 5                 A1  01Jan2018   6      0.000000  12495.434510
# 6                 A1  01Jan2018   7      0.000000  13087.171390
# 7                 A1  01Jan2018   8    440.632027  12760.456240
# 8                 A1  01Jan2018   9   1857.357063   9616.471722
# 9                 A1  01Jan2018  10   6914.158677   7242.276175
# 10                A1  01Jan2018  11  13004.227310   5649.864060
# 11                A1  01Jan2018  12  17076.341540   4769.081162
# 12                A1  01Jan2018  13  17618.359650   4746.184557
# 13                A1  01Jan2018  14  14573.637230   5109.410799
# ...

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\spyder\\utils\\help',
#  '',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\python36.zip',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\DLLs',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\T3BJ\\.ipython',
#  'C:\\Users\\T3BJ\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\astroid\\brain']

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Crypto              cProfile            mmap                spyder
# Cython              calendar            mmapfile            spyder_breakpoints
# IPython             certifi             mmsystem            spyder_io_dcm
# OpenSSL             cffi                modulefinder        spyder_io_hdf5
# PIL                 cgi                 more_itertools      spyder_profiler
# PyQt5               cgitb               mpmath              spyder_pylint
# __future__          chardet             msgpack             sqlalchemy
# _ast                chunk               msilib              sqlite3
# _asyncio            click               msvcrt              sre_compile
# _bisect             cloudpickle         multipledispatch    sre_constants
# _blake2             clyent              multiprocessing     sre_parse
# _bootlocale         cmath               navigator_updater   ssl
# ...

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.19.1.
